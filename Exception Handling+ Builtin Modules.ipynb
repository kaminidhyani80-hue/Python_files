# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %%
a=int(input("Enter the number"))
# Out:
# Enter the number ejj
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a=int(input("Enter the number"))
#
# ValueError: invalid literal for int() with base 10: 'ejj'

# %%
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(b)
#
# NameError: name 'b' is not defined

# %%
a= [1,2,3]
print(a[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 a= [1,2,3]
# ----> 2 print(a[5])
#
# IndexError: list index out of range

# %%
with open("abc.txt,"r") as f:
          print(f.read())
# Out:
#   Cell In[5], line 1
#     with open("abc.txt,"r") as f:
#                         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# Divide the two no. and print the result only if there is no error. At the end print " Division operation"

# %%
a = 5
b = 2
try:
    result = a/b
except:
    print("Division by zero")
else:
    print(result)
finally:
    print("Division Operation")
# Out:
# 2.5
# Division Operation

# %%
try:
    with open(r"abc.txt","w") as f:
        print(f.read())
except:
    print("file not found")
else:
    print(content)
finally:
    print("....File Handling done")
# Out:
# file not found
# ....File Handling done

# %% [markdown]
# Take number as input from user. Print square if input is valid, else print error.

# %%
try:
    a = int(input("Enter a number"))
except:
    print("Error")
else:
    print(a**2)
finally:
    print("Squaring is done!")
# Out:
# Enter a number 3.4
# Error
# Squaring is done!

# %%
try:
    a = int(input("Enter a number"))
except Exception as e:
    print(e)
# Out:
# Enter a number 4.5
# invalid literal for int() with base 10: '4.5'

# %%
try:
    with open("file.txt","r") as f:
        print(f.read())
except Exception as e:
    print(e)
# Out:
# [Errno 2] No such file or directory: 'file.txt'

# %%
a= [1,2,3]
try:
    print(a[5])
except Exception as e:
    print(e)
# Out:
# list index out of range

# %%
try:
    print(z)
except Exception as e:
    print(e)
# Out:
# name 'z' is not defined

# %%
import math
print(math.sqrt(25))
# Out:
# 5.0

# %%
print(math.pow(5,2))
# Out:
# 25.0

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.ceil(5.88))
# Out:
# 6

# %%
print(math.floor(5.88))
# Out:
# 5

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
import random
print(random.randint(1,6))
# Out:
# 5

# %%
print(random.randrange(1,10,2))   #odd number it will take 3 number start,stop,step
# Out:
# 7

# %%
print(random.randrange(0,10,2))    #even number
# Out:
# 2

# %%
fruits = ['apple','mango','grapes']
print(random.choice(fruits))
# Out:
# apple

# %%
fruits = ['apple','mango','grapes','strawberry']
print(random.choices(fruits, k=3))
# Out:
# ['strawberry', 'strawberry', 'grapes']

# %%
numbers = [1,2,3,4,5,6,7]
random.shuffle(numbers)
print(numbers)
# Out:
# [7, 3, 2, 5, 4, 1, 6]

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2026-04-05 21:33:25.614175

# %%
print(datetime.date.today())
# Out:
# 2026-04-05

# %%
print(datetime.date(2026,7,3))
# Out:
# 2026-07-03

# %%
import datetime
from datetime import timedelta
today = datetime.date.today()
print("Current Date",today)
future = today+timedelta(days=5)
print("Five days after is", future)
# Out:
# Current Date 2026-04-07
# Five days after is 2026-04-12

# %%
print(today.strftime("%d,%m,%Y"))
# Out:
# 07,04,2026

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\radha

# %%
import os
print(os.listdir())
# Out:
# ['.anaconda', '.android', '.bash_history', '.cache', '.chocolatey', '.conda', '.config', '.continuum', '.copilot', '.eclipse', '.emulator_console_auth_token', '.firebaserc', '.gitconfig', '.gitignore', '.gradle', '.ipynb_checkpoints', '.ipython', '.javacpp', '.jdks', '.jupyter', '.lc', '.lesshst', '.m2', '.node_repl_history', '.p2', '.python_history', '.redhat', '.skiko', '.vscode', 'abc.txt', 'AlgorithmVisualizer', 'anaconda_projects', 'AndroidStudioProjects', 'ansel', 'AppData', 'Apple', 'Application Data', 'Contacts', 'Cookies', 'CrossDevice', 'Documents', 'Downloads', 'Exception Handling+ Builtin Modules.ipynb', 'Favorites', 'firebase.json', 'Focus_session4.ipynb', 'for', 'functions', 'IdeaProjects', 'IntelGraphicsProfiles', 'java_error_in_idea64_12436.log', 'java_error_in_idea64_12960.log', 'java_error_in_idea64_16508.log', 'java_error_in_idea64_17784.log', 'java_error_in_idea64_18084.log', 'java_error_in_idea64_7212.log', 'java_error_in_idea64_7464.log', 'java_error_in_idea64_7
# ...

# %%
os.mkdir("test123")

# %% [markdown]
# to remove mkdir test123

# %%
os.rmdir("test123")
