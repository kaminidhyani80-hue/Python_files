# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\radha\onedrive\conda\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\radha\onedrive\conda\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\radha\onedrive\conda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\radha\onedrive\conda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\radha\onedrive\conda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\radha\onedrive\conda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# Create a pandas series

# %%
s = pd.Series([10,20,30,40])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# Create Series with custom index

# %%
s1 = pd.Series([10,20,30,40], index = ['a','b','c','d'])
s1
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %% [markdown]
# Create Series from dictionary

# %%
data = {'a':10,'b':20,'c':30,'d':40}
s2 = pd.Series(data)
s2
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %% [markdown]
# Make dataframe from dictionary

# %%
print(s2['b'])
# Out:
# 20

# %% [markdown]
# DataFrame with custom index

# %%
data = {
    'Math':[84,64,89,65],
    'Science':[78,98,78,89]
}
df = pd.DataFrame(data)         # indexing 0,1,2,3 came by defult.
df
# Out:
#    Math  Science
# 0    84       78
# 1    64       98
# 2    89       78
# 3    65       89

# %%
df1 = pd.DataFrame(data, index = ['a','b','c','d'])    # here we gave indexing.
df1
# Out:
#    Math  Science
# a    84       78
# b    64       98
# c    89       78
# d    65       89

# %% [markdown]
# DataFrame from Series

# %%
s1 = pd.Series([1, 2, 3])
s2 = pd.Series([4, 5, 6])

df = pd.DataFrame({'col1': s1, 'col2': s2})
df
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6

# %%
df1 = pd.DataFrame({
    'ShipmentID': [1001, 1002, 1003, 1004, 1005],
    'Origin': ['NY', 'SF', 'Dallas', 'Chicago', 'Miami'],
    'Destination': ['Boston', 'Seattle', 'Houston', 'Atlanta', 'Denver'],
    'Weight_kg': [12.5, 8.0, 15.0, 7.5, 10.0],
    'Fragile': [True, False, True, False, True],
    'Status': ['Delivered', 'In Transit', 'Delayed', 'Delivered', 'Delayed']
})

# %%
df1
# Out:
#    ShipmentID   Origin Destination  Weight_kg  Fragile      Status
# 0        1001       NY      Boston       12.5     True   Delivered
# 1        1002       SF     Seattle        8.0    False  In Transit
# 2        1003   Dallas     Houston       15.0     True     Delayed
# 3        1004  Chicago     Atlanta        7.5    False   Delivered
# 4        1005    Miami      Denver       10.0     True     Delayed

# %%
df1.shape
# Out:
# (5, 6)

# %%
df1.dtypes
# Out:
# ShipmentID       int64
# Origin          object
# Destination     object
# Weight_kg      float64
# Fragile           bool
# Status          object
# dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ShipmentID   5 non-null      int64
#  1   Origin       5 non-null      object
#  2   Destination  5 non-null      object
#  3   Weight_kg    5 non-null      float64
#  4   Fragile      5 non-null      bool
#  5   Status       5 non-null      object
# dtypes: bool(1), float64(1), int64(1), object(3)
# memory usage: 337.0+ bytes

# %%
df1['ShipmentID']            # here the output is Series
# Out:
# 0    1001
# 1    1002
# 2    1003
# 3    1004
# 4    1005
# Name: ShipmentID, dtype: int64

# %%
df1['Status']
# Out:
# 0     Delivered
# 1    In Transit
# 2       Delayed
# 3     Delivered
# 4       Delayed
# Name: Status, dtype: object

# %%
df1['Status'].value_counts()                    # important function
# Out:
# Status
# Delivered     2
# Delayed       2
# In Transit    1
# Name: count, dtype: int64

# %%
df1.columns
# Out:
# Index(['ShipmentID', 'Origin', 'Destination', 'Weight_kg', 'Fragile',
#        'Status'],
#       dtype='object')

# %%
data = {
    'A': [101,102,103],
    'B':[201,202,203],
    'C': [301,302,303]
    }
s1 = pd.DataFrame(data, index=['a','b','c'])
s1
# Out:
#      A    B    C
# a  101  201  301
# b  102  202  302
# c  103  203  303

# %% [markdown]
# Select column

# %%
s1['B']
# Out:
# a    201
# b    202
# c    203
# Name: B, dtype: int64

# %% [markdown]
# Multiple columns

# %%
s1[['B','C']]
# Out:
#      B    C
# a  201  301
# b  202  302
# c  203  303

# %% [markdown]
# loc (label-based)

# %%
s1.loc['a']
# Out:
# A    101
# B    201
# C    301
# Name: a, dtype: int64

# %%
s1.loc['c']
# Out:
# A    103
# B    203
# C    303
# Name: c, dtype: int64

# %%
print(s1.loc['b','B'])
# Out:
# 202

# %%
print(s1.loc['c','B'])
# Out:
# 203

# %% [markdown]
# iloc (index-based)

# %%
s1.iloc[0]
# Out:
# A    101
# B    201
# C    301
# Name: a, dtype: int64

# %%
s1.iloc[1]
# Out:
# A    102
# B    202
# C    302
# Name: b, dtype: int64

# %%
print(s1.iloc[1,1])
# Out:
# 202

# %%
df1
# Out:
#    ShipmentID   Origin Destination  Weight_kg  Fragile      Status
# 0        1001       NY      Boston       12.5     True   Delivered
# 1        1002       SF     Seattle        8.0    False  In Transit
# 2        1003   Dallas     Houston       15.0     True     Delayed
# 3        1004  Chicago     Atlanta        7.5    False   Delivered
# 4        1005    Miami      Denver       10.0     True     Delayed

# %% [markdown]
# How will you filter rows where Weight > 10 using loc?

# %%
df1.loc[df1['Weight_kg']>10]
# Out:
#    ShipmentID  Origin Destination  Weight_kg  Fragile     Status
# 0        1001      NY      Boston       12.5     True  Delivered
# 2        1003  Dallas     Houston       15.0     True    Delayed

# %% [markdown]
# How will you select only 'Destination' column?

# %%
df1['Destination']
# Out:
# 0     Boston
# 1    Seattle
# 2    Houston
# 3    Atlanta
# 4     Denver
# Name: Destination, dtype: object

# %% [markdown]
# Cost = Weight * 10?

# %%
df1['Cost'] = df1['Weight_kg']*10               #created new column

# %%
df1
# Out:
#    ShipmentID   Origin Destination  Weight_kg  Fragile      Status   Cost
# 0        1001       NY      Boston       12.5     True   Delivered  125.0
# 1        1002       SF     Seattle        8.0    False  In Transit   80.0
# 2        1003   Dallas     Houston       15.0     True     Delayed  150.0
# 3        1004  Chicago     Atlanta        7.5    False   Delivered   75.0
# 4        1005    Miami      Denver       10.0     True     Delayed  100.0

# %%
df
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6

# %%
import pandas as pd

df = pd.DataFrame({
    'Name': ['Amit', 'Sara', 'John', 'Priya', 'Ravi'],
    'Math': [80, 90, 75, 85, 60],
    'Science': [70, 95, 80, 75, 65],
    'Passed': [True, True, True, True, False]
})

# %%
df
# Out:
#     Name  Math  Science  Passed
# 0   Amit    80       70    True
# 1   Sara    90       95    True
# 2   John    75       80    True
# 3  Priya    85       75    True
# 4   Ravi    60       65   False

# %% [markdown]
# How many rows and columns are there?

# %%
df.shape                              # can also use info
# Out:
# (5, 4)

# %% [markdown]
# What are the column names?

# %%
df.columns
# Out:
# Index(['Name', 'Math', 'Science', 'Passed'], dtype='object')

# %% [markdown]
# What is the data type of each column?

# %%
df.dtypes
# Out:
# Name       object
# Math        int64
# Science     int64
# Passed       bool
# dtype: object

# %% [markdown]
# How will you select only the Math marks column?

# %%
df['Math']
# Out:
# 0    80
# 1    90
# 2    75
# 3    85
# 4    60
# Name: Math, dtype: int64

# %% [markdown]
# How will you select Name and Science columns together?

# %%
df[['Math','Science']]
# Out:
#    Math  Science
# 0    80       70
# 1    90       95
# 2    75       80
# 3    85       75
# 4    60       65

# %% [markdown]
# How will you get the first row?

# %%
df.iloc[0]
# Out:
# Name       Amit
# Math         80
# Science      70
# Passed     True
# Name: 0, dtype: object

# %% [markdown]
# How will you get the last row?

# %%
df.iloc[-1]
# Out:
# Name        Ravi
# Math          60
# Science       65
# Passed     False
# Name: 4, dtype: object

# %% [markdown]
# How will you get the 2nd row and 3rd column value?

# %%
print(df.iloc[1,2])
# Out:
# 95

# %% [markdown]
# How will you get first 3 rows?

# %%
df.iloc[0:3]
# Out:
#    Name  Math  Science  Passed
# 0  Amit    80       70    True
# 1  Sara    90       95    True
# 2  John    75       80    True

# %% [markdown]
# How will you get rows 2 to 4 and columns 1 to 2?

# %%
df.iloc[1:4,0:2]
# Out:
#     Name  Math
# 1   Sara    90
# 2   John    75
# 3  Priya    85

# %% [markdown]
# How will you get all students who passed?

# %%
df[df['Passed']==True]
# Out:
#     Name  Math  Science  Passed
# 0   Amit    80       70    True
# 1   Sara    90       95    True
# 2   John    75       80    True
# 3  Priya    85       75    True

# %% [markdown]
# How will you get students with Math > 80 AND Science > 80?

# %%
df[(df['Math']>80) & (df['Science']>80)]
# Out:
#    Name  Math  Science  Passed
# 1  Sara    90       95    True

# %% [markdown]
# How will you create a new column Total = Math + Science?

# %%
df['Total'] = df['Math']+df['Science']     
df
# Out:
#     Name  Math  Science  Passed  Total
# 0   Amit    80       70    True    150
# 1   Sara    90       95    True    185
# 2   John    75       80    True    155
# 3  Priya    85       75    True    160
# 4   Ravi    60       65   False    125

# %% [markdown]
# How will you create Average marks?

# %%
df['Average'] = df['Total']/2
df
# Out:
#     Name  Math  Science  Passed  Total  Average
# 0   Amit    80       70    True    150     75.0
# 1   Sara    90       95    True    185     92.5
# 2   John    75       80    True    155     77.5
# 3  Priya    85       75    True    160     80.0
# 4   Ravi    60       65   False    125     62.5

# %% [markdown]
# Above 80 → Excellent, else Average. Create new column called category

# %%
def remark(marks):
    if marks>80:
        return "Excellent"
    else:
        return "Average"
df['Category'] = df['Average'].apply(remark)        
df
# Out:
#     Name  Math  Science  Passed  Total  Average   Category
# 0   Amit    80       70    True    150     75.0    Average
# 1   Sara    90       95    True    185     92.5  Excellent
# 2   John    75       80    True    155     77.5    Average
# 3  Priya    85       75    True    160     80.0    Average
# 4   Ravi    60       65   False    125     62.5    Average

# %% [markdown]
# How will you label Passed column:
#
# True → "Yes", False → "No"

# %%
def grade(result):
    if result==True:
        return"Yes"
    else:
        return "No"
df['Lable']=df['Passed'].apply(grade)

# %%
df
# Out:
#     Name  Math  Science  Passed  Total  Average   Category Lable
# 0   Amit    80       70    True    150     75.0    Average   Yes
# 1   Sara    90       95    True    185     92.5  Excellent   Yes
# 2   John    75       80    True    155     77.5    Average   Yes
# 3  Priya    85       75    True    160     80.0    Average   Yes
# 4   Ravi    60       65   False    125     62.5    Average    No

# %% [markdown]
# How will you rename column Math → Maths?

# %%
df[df['Math'] == df['Maths']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\conda\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Maths'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 df[df['Math'] == df['Maths']]
#
# File ~\OneDrive\conda\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\OneDrive\conda\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Maths'

# %% [markdown]
# How will you drop column Science?

# %% [markdown]
# What is the average Math score of class?

# %% [markdown]
# How many students passed?

# %% [markdown]
# read_csv
