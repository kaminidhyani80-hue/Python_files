# %%
print("I love python")
# Out:
# I love python

# %%
print("India is beutiful")
# Out:
# India is beutiful

# %%
a = 1
b = 0.5
c = True
d = "India"

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# bool

# %%
type(d)
# Out:
# str

# %%
a = 2
b = 3
print("Addition of two numbers is",a+b)
# Out:
# Addition of two numbers is 5

# %%
a = 3
b = 2
print("subtraction of two numbers is",a-b)
# Out:
# subtraction of two numbers is 1

# %%
a = int(input("Enter the first number"))
b = int(input("Enter the second number"))
print("Addition of two numbers is",a+b)
print("Subtraction of two numbers is",a-b)
print("Multiplication of two numbers is",a*b)
print("Division of two numbers is",a/b)
# Out:
# Enter the first number 20
# Enter the second number 2
# Addition of two numbers is 22
# Subtraction of two numbers is 18
# Multiplication of two numbers is 40
# Division of two numbers is 10.0

# %%
aa = 53

# %%
type(aa)
# Out:
# int

# %%
aa = aa + 0.1      #Example of Implicit
type(aa)
# Out:
# float

# %%
bb = "53"
type(bb)
# Out:
# str

# %%
bb = int(bb)       #Example of Explicit
type(bb)
# Out:
# int

# %% [markdown]
# ## F-String

# %%
a = 5
b = 3
print(f"Addition of {a} and {b} is {a+b}")
# Out:
# Addition of 5 and 3 is 8

# %%
name = input("Enter the name of the guest")
print(f"Hello, {name} welcome to my humble abode")
# Out:
# Enter the name of the guest sheena
# Hello, sheena welcome to my humble abode

# %%
first_name = input("Enter the name the name")
last_name = input("Enter the name")
print(f"Hello, {first_name} {last_name}, whatsup!!")
# Out:
# Enter the name the name Ram
# Enter the name sharma
# Hello, Ram sharma, whatsup!!

# %% [markdown]
# ## whether the name is even or odd

# %%
n = int(input("Enter the number"))
if n%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter the number 30
# Even
