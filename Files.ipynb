# %%
with open(r"C:\Users\radha\OneDrive\Documents\python_notepad\hello.txt","w") as f:
    f.write("Hello,India")

# %%
with open(r"C:\Users\radha\OneDrive\Documents\python_notepad\hello.txt","r") as f:
    print(f.read())
# Out:
# Hello,India

# %%
with open(r"C:\Users\radha\OneDrive\Documents\python_notepad\hello.txt","w") as f:
    f.write("\nHello, Indiawalo")

# %%
data = ["apple","mango","strawberry"]
with open(r"C:\Users\radha\OneDrive\Documents\python_notepad\fruits.txt","w") as f:
    for i in data:
        f.write("\n"+i)

# %%
with open(r"C:\Users\radha\OneDrive\Documents\python_notepad\fruits.txt","r") as f:
    print(f.read())
# Out:
# apple
# mango
# strawberry

# %%
data = ["\nappple","\nmango","\nstrawberry"]
with open(r"C:\Users\radha\OneDrive\Documents\python_notepad\fruits.txt","w") as f:
    f.writelines(data)

# %%
with open(r"C:\Users\radha\OneDrive\Documents\python_notepad\fruits.txt","r") as f:
    print(f.read())
# Out:
# appple
# mango
# strawberry

# %%
import csv
with open(r"C:\Users\radha\OneDrive\Documents\python_notepad\students.csv","w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["Name","Age","City"])
    writer.writerow(["DEF", 45,"Delhi"])

# %%
import csv
with open(r"C:\Users\radha\OneDrive\Documents\python_notepad\students.csv","r") as f:
    reader = csv.reader(f)
    for i in reader:
        print(i)
# Out:
# ['Name', 'Age', 'City']
# ['DEF', '45', 'Delhi']

# %%
import csv
with open(r"C:\Users\radha\OneDrive\Documents\python_notepad\students.csv","w", newline="") as f:
     writer=csv.writer(f)
     writer.writerow(["EFG","67","Goa"])
     writer.writerow(["PQR", 45,"Goa"])
